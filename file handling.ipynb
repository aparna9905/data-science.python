# %%
#file handling
file=open('cgc_winter.txt','w')

# %%
file.write('hello')
# Out:
# 5

# %%
file.close()

# %%
file=open('new_cgc_winter.txt', 'w')

# %%
file.write('i am here')
# Out:
# 9

# %%
file.close
# Out:
# <function TextIOWrapper.close()>

# %%
file=open('new_cgc_winter.txt', 'a')

# %%
file.write('hello this is a new line\n')
# Out:
# 25

# %%
file.close
# Out:
# <function TextIOWrapper.close()>

# %%
file=open('new_cgc_winter.txt', 'r')

# %%
file.read()
# Out:
# '\nthis\nthis\nthis\nthishello this is a new line\n'

# %%
file.seek(0) #wapis 0 pe lana hai.. kyuki 0 se start ho krna hai..f
# Out:
# 0

# %%
content=file.read()

# %%
print(content)
# Out:
# ----------------------------------------------------------------
# NameError                      Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(content)
#
# NameError: name 'content' is not defined
