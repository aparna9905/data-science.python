# %%
#lambda :- one linear

# %%
def add(a,b):
    print(a+b)

# %%
add(4,5)
# Out:
# 9

# %%
add1= lambda a,b: a+b

# %%
a = add1(2,3)

# %%
a
# Out:
# 5

# %%
is_even=lambda a : a % 2 == 0

# %%
is_even(8)
# Out:
# True

# %%
greater=lambda a,b: a if a>b else b

# %%
greater(5,7)
# Out:
# 7

# %%
even= lambda a : "even" if a % 2 == 0 else "odd"

# %%
even(8)
# Out:
# 'even'

# %%
def sqr(x):
    return x*x

# %%
sqr(5)
# Out:
# 25

# %%
nums=[2,3,5,6,7]

# %%
list(map(sqr,nums))
# Out:
# [4, 9, 25, 36, 49]

# %%
list(map(lambda x: x*x, nums))
# Out:
# [4, 9, 25, 36, 49]

# %%
list(map(lambda x: x*x*x, nums))
# Out:
# [8, 27, 125, 216, 343]

# %%
list(map(lambda x: "even" if x % 2==0 else "odd" ,nums))
# Out:
# ['even', 'odd', 'odd', 'even', 'odd']

# %%
list(filter(lambda x: x % 2 ==1, nums))
# Out:
# [3, 5, 7]

# %%
marks=[23,30,35,40]

# %%
marks=[23,30,35,40]

result = list(filter(lambda x :x+5 if x>30 else "fail",marks))
print(result)
# Out:
# [23, 30, 35, 40]

# %%
a=10

# %%
a+=1

# %%
print(a)
# Out:
# 11

# %%
account=1000
debit=0
credit=0

# %%
def credit(amount):
    global account
    account+=amount

# %%
credit(1000)

# %%
print(account)
# Out:
# 2000

# %%
def credit(amount):
    global account
    account += amount

# %%
credit(500)

# %%
print(account)
# Out:
# 2500
