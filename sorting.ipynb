# %%
list1 = []

# %%
type(list1)
# Out:
# list

# %%
list2=['king','queen','rock', 22, 6.5]

# %%
print(list2)
# Out:
# ['king', 'queen', 'rock', 22, 6.5]

# %%
print(list2[1])
# Out:
# queen

# %%
print(list2[-1])
# Out:
# 6.5

# %%
print(list2[1:])
# Out:
# ['queen', 'rock', 22, 6.5]

# %%
print(list2[:3])
# Out:
# ['king', 'queen', 'rock']

# %%
list2[2]='leaf'

# %%
print(list2)
# Out:
# ['king', 'queen', 'leaf', 22, 6.5]

# %%
list2.index('queen')
# Out:
# 1

# %%
list3=['king', 'queen', 'rookie', 'big', 'rock', 'queen', 'rookie', 'pawn']

# %%
list3
# Out:
# ['king', 'queen', 'rookie', 'big', 'rock', 'queen', 'rookie', 'pawn']

# %%
list3.index('queen')
# Out:
# 1

# %%
list3.count('queen')
# Out:
# 2

# %%
list4=[33,44,56,65,78,98,23,45,99,101]

# %%
list4.sort()

# %%
print(list4)
# Out:
# [23, 33, 44, 45, 56, 65, 78, 98, 99, 101]

# %%
list5=[33,44,56,65,78,98,23,45,99,101]

# %%
list5.sort(reverse=True)

# %%
print(list5)
# Out:
# [101, 99, 98, 78, 65, 56, 45, 44, 33, 23]

# %%
list5.append('roger')

# %%
print(list5)
# Out:
# [101, 99, 98, 78, 65, 56, 45, 44, 33, 23, 'roger']

# %%
print(list3)
# Out:
# ['king', 'queen', 'rookie', 'big', 'rock', 'queen', 'rookie', 'pawn']

# %%
list3.index('rookie', 2)
# Out:
# 2

# %%
list3.pop(5)
# Out:
# 'queen'

# %%
list3
# Out:
# ['king', 'queen', 'rookie', 'big', 'rock', 'rookie', 'pawn']

# %%
list3.extend([2,3,4])

# %%
print(list3)
# Out:
# ['king', 'queen', 'rookie', 'big', 'rock', 'rookie', 'pawn', 2, 3, 4]

# %%
list3.extend(list4)

# %%
print(list3)
# Out:
# ['king', 'queen', 'rookie', 'big', 'rock', 'rookie', 'pawn', 2, 3, 4, 23, 33, 44, 45, 56, 65, 78, 98, 99, 101]

# %%
list3.insert(3,'paul')

# %%
print(list3)
# Out:
# ['king', 'queen', 'rookie', 'paul', 'big', 'rock', 'rookie', 'pawn', 2, 3, 4, 23, 33, 44, 45, 56, 65, 78, 98, 99, 101]

# %%
list3.insert(3,'list3')

# %%
print(list3)
# Out:
# ['king', 'queen', 'rookie', 'list3', 'paul', 'big', 'rock', 'rookie', 'pawn', 2, 3, 4, 23, 33, 44, 45, 56, 65, 78, 98, 99, 101]

# %%
print(list3[3][0:1])
# Out:
# l

# %%
list6=[1,2,3,4,5]

# %%
list7=['a', 'b', 'c', 'd']

# %%
list6.insert(3,list7)

# %%
print(list6)
# Out:
# [1, 2, 3, ['a', 'b', 'c', 'd'], 4, 5]

# %%
print(list6[3][0:2])
# Out:
# ['a', 'b']

# %%
list6[3].append('roger')

# %%
print(list6[3])
# Out:
# ['a', 'b', 'c', 'd', 'roger']

# %%
name='raja'

# %%
list6.append(name)

# %%
list6
# Out:
# [1, 2, 3, ['a', 'b', 'c', 'd', 'roger'], 4, 5, 'raja']

# %%
  #tuple

# %%
tup = ('king', 'queen', 'gagan',12 ,2 ,3 ,4 
       ,5)
print(tup)
# Out:
# ('king', 'queen', 'gagan', 12, 2, 3, 4, 5)

# %%
type(tup)
# Out:
# tuple

# %%
type[3]
# Out:
# type[3]

# %%
tup.count('queen')
# Out:
# 1

# %% [markdown]
# # tup.index('queen')

# %%
x=list(tup)

# %%
print(x)
# Out:
# ['king', 'queen', 'gagan', 12, 2, 3, 4, 5]

# %%
type(x)
# Out:
# list

# %%
x=tuple(x)

# %%
type(x)
# Out:
# tuple

# %%
tuple
# Out:
# tuple

# %%
student={'name':'Aparna','contact':748832844}

# %%
print(student)
# Out:
# {'name': 'Aparna', 'contact': 748832844}

# %%
print(student["name"])
# Out:
# Aparna

# %%
student['name']='shambhavi'

# %%
print(student['name'])
# Out:
# shambhavi

# %%
student['address']='chandigarh'

# %%
print(student['address'])
# Out:
# chandigarh

# %%
student.update({'name':'manash',
               'contact' : 7488832844})

# %%
print(student)
# Out:
# {'name': 'manash', 'contact': 7488832844, 'address': 'chandigarh'}

# %%
student.pop('address')
# Out:
# 'chandigarh'

# %%
print(student)
# Out:
# {'name': 'manash', 'contact': 7488832844}

# %%
del student ['name']

# %%
print(student)
# Out:
# {'contact': 7488832844}

# %%
student.update({'subject': 'data science', 'address' : 'chandigarh'})

# %%
student
# Out:
# {'contact': 7488832844, 'subject': 'data science', 'address': 'chandigarh'}

# %%
print(student.get('contact2', 'value not found'))
# Out:
# value not found

# %%
students={
    'student1': {
        'name': 'shambhavi',
        'roll no' : 789456
    },
    'student2' : {
        'name' :'Aparna',
        'roll no' : 123456
    }
}

# %%
print(students['student1']['name'])
# Out:
# shambhavi

# %%
print(len(students['student1']))
# Out:
# 2

# %%
students.keys()
# Out:
# dict_keys(['student1', 'student2'])

# %%
students.values()
# Out:
# dict_values([{'name': 'shambhavi', 'roll no': 789456}, {'name': 'Aparna', 'roll no': 123456}])

# %%
students.items()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 students.items()
#
# NameError: name 'students' is not defined
